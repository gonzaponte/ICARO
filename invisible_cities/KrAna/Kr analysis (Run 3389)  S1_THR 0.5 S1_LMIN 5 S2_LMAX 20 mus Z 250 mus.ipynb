# %% [markdown]
# # Kr analysis (run 3389)

# %%
from __future__ import print_function, division

import os
import operator
import functools
import copy
import time
import glob
print("Running on ", time.asctime())

import numpy as np
import tables as tb
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib inline

import invisible_cities.database.load_db as DB
import invisible_cities.core.system_of_units_c as SystemOfUnits
import invisible_cities.reco.pmaps_functions as pmapf
import invisible_cities.core.fit_functions as fitf

DataPMT = DB.DataPMT()
DataSiPM = DB.DataSiPM()
units = SystemOfUnits.SystemOfUnits()
pi = np.pi
# Out:
# Running on  Tue Mar 28 16:20:20 2017

# %% [markdown]
# #### General plotting options

# %%
plt.rcParams["figure.figsize"]          = 8, 6
plt.rcParams["font.size"]               = 15
plt.rcParams["figure.max_open_warning"] = 100

profOpt = "--k"
fitOpt  = "r"

outputfolder = "plots/run3389/Z250/"
if not os.path.exists(outputfolder):
    os.mkdir(outputfolder)

# %% [markdown]
# #### Useful functions

# %%
def width(times, to_mus=False):
    """
    Compute peak width.
    """
    w = (np.max(times) - np.min(times)) if np.any(times) else 0.
    return w * units.ns/units.mus if to_mus else w


def timefunc(f):
    """
    Decorator for function timing.
    """
    def time_f(*args, **kwargs):
        t0 = time.time()
        output = f(*args, **kwargs)
        print("Time spent in {}: {} s".format(f.__name__,
                                              time.time() - t0))
        return output
    return time_f


def integrate_charge(d):
    """
    Integrate charge from a SiPM dictionary.
    """
    newd = dict((key, np.sum(value)) for key, value in d.items())
    return map(np.array, list(zip(*newd.items())))


def flat(nested_list):
    while hasattr(nested_list[0], "__iter__"):
        nested_list = [item for inner_list in nested_list for item in inner_list]
    return np.array(nested_list)


def labels(xlabel, ylabel):
    """
    Set x and y labels.
    """
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)


def hist(*args, **kwargs):
    """
    Create a figure and then the histogram
    """
    plt.figure()
    return plt.hist(*args, **kwargs)


def doublehist(data1, data2, lbls, *args, **kwargs):
    """
    Create a figure and then the histogram
    """
    plt.figure()
    h1 = plt.hist(data1, *args, label=lbls[0], alpha=0.5, normed=True, **kwargs)
    h2 = plt.hist(data2, *args, label=lbls[1], alpha=0.5, normed=True, **kwargs)
    return h1, h2, plt.legend()

    
def hist2d(*args, **kwargs):
    """
    Create a figure and then the histogram
    """
    plt.figure()
    return plt.hist2d(*args, **kwargs)

    
def pdf(data, *args, **kwargs):
    """
    Create a normalized histogram with appropiate range.
    """
    data = np.array(data)
    h = hist(data, *args, **kwargs, weights=np.ones_like(data)/len(data))
    plt.yscale("log")
    plt.ylim(1e-4, 1.)
    return h
    
def scatter(*args, **kwargs):
    """
    Create a figure and then a scatter plot
    """
    plt.figure()
    return plt.scatter(*args, **kwargs)


def doublescatter(x1, y1, x2, y2, lbls, *args, **kwargs):
    """
    Create a figure and then a scatter plot
    """
    plt.figure()
    sc1 = plt.scatter(x1, y1, *args, label=lbls[0], **kwargs)
    sc2 = plt.scatter(x2, y2, *args, label=lbls[1], **kwargs)
    return sc1, sc2, plt.legend()


def save_to_folder(outputfolder, name):
    """
    Set title and save plot in folder.
    """
    plt.title(name)
    plt.savefig("{}/{}.png".format(outputfolder, name), dpi=100)

save = functools.partial(save_to_folder, outputfolder)

# %% [markdown]
# ### Input data

# %%
# Comment out this line if your data is in $IC_DATA
os.environ["IC_DATA"] = os.environ["IC_DATA"] + "/Kr2016/data/3389/"

# %%
pattern = "$IC_DATA/pmaps_waves.gdcsnext.*_3389.root.h5"
ifiles  = glob.glob(os.path.expandvars(pattern))
print("# files:", len(ifiles))
# Out:
# # files: 2997

# %% [markdown]
# ### Define event class

# %%
class Event:
    """
    Store for relevant event info.
    """
    def __init__(self):
        self.nS1   = 0
        self.S1w   = []
        self.S1h   = []
        self.S1i   = []
        self.S1t   = []

        self.nS2   = 0
        self.S2w   = []
        self.S2h   = []
        self.S2i   = []
        self.S2t   = []

        self.Nsipm = []
        self.Q     = []
        self.Qsipm = []
        self.Xt    = np.nan
        self.Yt    = np.nan
        self.X     = np.nan
        self.Y     = np.nan
        self.Xrms  = np.nan
        self.Yrms  = np.nan
        self.Z     = np.nan
        self.R     = np.nan
        self.Phi   = np.nan

        self.T     = -1
        self.ok    = False

# %% [markdown]
# ### Define dataset class

# %%
class Dataset:
    """
    Trick for accesing event properties as an attribute of the dataset.
    """
    def __init__(self, evts):
        self.evts = np.array(evts, dtype=object)
        self._create_attrs()
    
    @timefunc
    def _create_attrs(self):
        for attr in filter(lambda x: not x.endswith("__"), Event().__dict__):
            setattr(self, attr, np.array([getattr(evt, attr) for evt in self.evts]))

    def __getitem__(self, sel):
        return Dataset(self.evts[sel])

# %% [markdown]
# ## Functions to fill the event and dataset classes

# %%
#@timefunc
def fill_evts(s1s, s2s, sis, evts_out, times, ifile=None):    
    evts = set(list(s1s.keys()) +
               list(s2s.keys()) +
               list(sis.keys()))
    nevt = len(evts)
    print(ifile, nevt)
    for i, evt_number in enumerate(evts):
        evt = Event()
        s1  = s1s.get(evt_number, dict())
        s2  = s2s.get(evt_number, dict())
        si  = sis.get(evt_number, dict())
        
        evt.nS1 = 0
        evt.nS2 = 0

        s1time = 0
        for peak, (t, e) in s1.items():
            sel  = e > 0.5
            t, e = t[sel], e[sel]
            if t.size < 5:
                continue
            evt.nS1 += 1
            evt.S1w.append(width(t))
            evt.S1h.append(np.max(e))
            evt.S1i.append(np.sum(e))
            s1time = t[np.argmax(e)]
            evt.S1t.append(s1time)
        
        s2time = 0
        for peak, (t, e) in s2.items():
            w = width(t, to_mus=True)
            if w>20:
                continue
            evt.nS2 += 1
            evt.S2w.append(w)
            evt.S2h.append(np.max(e))
            evt.S2i.append(np.sum(e))
            s2time = t[np.argmax(e)]
            evt.S2t.append(s2time)
            
            IDs, Qs = integrate_charge(si[peak]) if peak in si else ([], [])
            Qpeak   = np.sum(Qs)
            xsipms  = DataSiPM.X.values[IDs]
            ysipms  = DataSiPM.Y.values[IDs]

            evt.Qsipm.append(Qs)
            evt.Nsipm.append(len(IDs))
            evt.Q    .append(Qpeak)
            evt.X    = np.average(xsipms, weights=Qs) if np.any(Qs) else np.nan
            evt.Y    = np.average(ysipms, weights=Qs) if np.any(Qs) else np.nan
            evt.Xrms = (np.sum(Qs * (xsipms-evt.X)**2) / (Qpeak - 1))**0.5 if np.any(Qs) else np.nan
            evt.Yrms = (np.sum(Qs * (ysipms-evt.Y)**2) / (Qpeak - 1))**0.5 if np.any(Qs) else np.nan
            evt.R    = (evt.X**2 + evt.Y**2)**0.5 if np.any(Qs) else np.nan
            evt.Phi  = np.arctan2(evt.Y, evt.X) if np.any(Qs) else np.nan

        evt.T  = times[i]
        evt.ok = evt.nS1 == evt.nS2 == 1
        if evt.ok:
            evt.Z = (s2time - s1time) * units.ns / units.mus
        evts_out.append(evt)


@timefunc
def build_dataset(inputfiles):
    evts_out = []
    for ifile in inputfiles:
        s1s, s2s, sis = pmapf.read_pmaps(ifile)
        with tb.open_file(ifile) as h5f:
            times = h5f.root.Run.events.cols.timestamp[:] * 1e-3
        fill_evts(pmapf.df_to_pmaps_dict(s1s),
                  pmapf.df_to_pmaps_dict(s2s),
                  pmapf.df_to_s2si_dict (sis),
                  evts_out, times - np.min(times), ifile)
    return Dataset(evts_out)

# %% [markdown]
# # Read data

# %%
full = build_dataset(ifiles)
# Out:
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.000_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.001_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.002_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.003_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.004_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.005_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.006_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.007_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.008_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.009_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.010_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.011_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.012_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.013_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.014_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.015_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.016_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.017_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.018_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.019_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.020_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.021_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.022_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.023_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.024_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.025_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.026_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.027_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.028_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.029_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.030_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.031_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.032_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.033_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.034_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.035_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.036_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.037_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.038_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.039_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.040_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.041_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.042_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.043_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.044_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.045_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.046_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.047_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.048_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.049_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.050_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.051_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.052_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.053_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.054_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.055_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.056_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.057_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.058_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.059_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.060_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.061_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.062_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.063_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.064_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.065_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.066_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.067_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.068_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.069_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.070_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.071_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.072_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.073_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.074_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.075_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.076_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.077_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.078_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.079_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.080_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.081_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.082_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.083_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.084_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.085_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.086_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.087_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.088_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.089_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.090_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.091_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.092_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.093_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.094_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.095_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.096_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.097_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.098_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.099_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1000_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1001_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1002_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1003_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1004_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1005_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1006_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1007_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1008_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1009_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.100_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1010_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1011_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1012_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1013_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1014_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1015_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1016_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1017_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1018_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1019_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.101_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1020_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1021_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1022_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1023_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1024_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1025_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1026_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1027_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1028_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1029_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.102_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1030_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1031_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1032_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1033_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1034_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1035_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1036_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1037_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1038_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1039_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.103_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1040_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1041_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1042_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1043_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1044_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1045_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1046_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1047_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1048_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1049_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.104_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1050_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1051_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1052_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1053_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1054_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1055_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1056_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1057_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1058_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1059_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.105_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1060_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1061_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1062_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1063_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1064_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1065_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1066_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1067_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1068_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1069_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.106_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1070_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1071_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1072_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1073_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1074_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1075_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1076_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1077_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1078_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1079_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.107_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1080_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1081_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1082_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1083_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1084_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1085_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1086_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1087_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1088_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1089_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.108_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1090_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1091_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1092_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1093_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1094_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1095_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1096_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1097_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1098_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1099_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.109_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1100_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1101_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1102_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1103_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1104_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1105_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1106_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1107_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1108_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1109_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.110_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1110_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1111_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1112_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1113_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1114_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1115_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1116_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1117_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1118_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1119_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.111_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1120_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1121_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1122_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1123_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1124_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1125_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1126_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1127_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1128_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1129_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.112_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1130_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1131_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1132_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1133_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1134_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1135_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1136_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1137_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1138_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1139_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.113_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1140_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1141_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1142_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1143_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1144_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1145_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1146_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1147_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1148_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1149_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.114_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1150_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1151_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1152_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1153_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1154_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1155_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1156_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1157_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1158_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1159_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.115_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1160_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1161_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1162_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1163_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1164_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1165_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1166_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1167_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1168_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1169_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.116_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1170_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1171_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1172_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1173_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1174_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1175_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1176_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1177_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1178_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1179_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.117_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1180_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1181_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1182_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1183_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1184_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1185_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1186_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1187_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1188_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1189_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.118_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1190_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1191_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1192_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1193_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1194_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1195_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1196_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1197_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1198_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1199_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.119_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1200_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1201_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1202_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1203_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1204_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1205_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1206_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1207_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1208_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1209_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.120_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1210_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1211_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1212_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1213_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1214_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1215_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1216_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1217_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1218_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1219_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.121_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1220_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1221_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1222_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1223_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1224_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1225_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1226_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1227_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1228_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1229_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.122_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1230_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1231_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1232_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1233_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1234_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1235_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1236_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1237_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1238_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1239_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.123_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1240_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1241_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1242_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1243_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1244_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1245_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1246_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1247_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1248_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1249_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.124_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1250_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1251_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1252_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1253_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1254_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1255_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1256_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1257_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1258_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1259_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.125_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1260_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1261_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1262_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1263_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1264_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1265_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1266_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1267_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1268_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1269_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.126_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1270_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1271_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1272_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1273_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1274_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1275_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1276_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1277_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1278_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1279_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.127_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1280_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1281_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1282_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1283_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1284_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1285_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1286_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1287_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1288_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1289_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.128_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1290_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1291_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1292_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1293_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1294_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1295_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1296_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1297_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1298_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1299_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.129_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1300_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1301_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1302_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1303_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1304_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1305_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1306_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1307_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1308_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1309_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.130_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1310_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1311_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1312_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1313_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1314_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1315_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1316_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1317_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1318_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1319_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.131_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1320_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1321_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1322_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1323_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1324_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1325_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1326_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1327_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1328_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1329_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.132_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1330_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1331_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1332_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1333_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1334_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1335_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1336_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1337_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1338_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1339_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.133_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1340_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1341_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1342_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1343_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1344_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1345_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1346_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1347_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1348_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1349_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.134_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1350_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1351_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1352_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1353_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1354_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1355_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1356_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1357_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1358_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1359_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.135_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1360_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1361_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1362_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1363_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1364_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1365_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1366_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1367_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1368_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1369_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.136_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1370_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1371_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1372_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1373_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1374_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1375_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1376_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1377_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1378_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1379_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.137_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1380_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1381_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1382_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1383_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.1384_3389.root.h5 163
# ...
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.826_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.827_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.828_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.829_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.830_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.831_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.832_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.833_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.834_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.835_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.836_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.837_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.838_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.839_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.840_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.841_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.842_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.843_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.844_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.845_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.846_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.847_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.848_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.849_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.850_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.851_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.852_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.853_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.854_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.855_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.856_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.857_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.858_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.859_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.860_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.861_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.862_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.863_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.864_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.865_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.866_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.867_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.868_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.869_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.870_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.871_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.872_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.873_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.874_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.875_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.876_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.877_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.878_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.879_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.880_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.881_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.882_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.883_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.884_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.885_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.886_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.887_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.888_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.889_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.890_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.891_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.892_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.893_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.894_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.895_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.896_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.897_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.898_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.899_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.900_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.901_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.902_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.903_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.904_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.905_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.906_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.907_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.908_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.909_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.910_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.911_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.912_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.913_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.914_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.915_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.916_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.917_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.918_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.919_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.920_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.921_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.922_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.923_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.924_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.925_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.926_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.927_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.928_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.929_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.930_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.931_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.932_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.933_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.934_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.935_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.936_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.937_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.938_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.939_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.940_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.941_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.942_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.943_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.944_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.945_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.946_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.947_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.948_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.949_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.950_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.951_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.952_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.953_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.954_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.955_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.956_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.957_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.958_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.959_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.960_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.961_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.962_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.963_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.964_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.965_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.966_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.967_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.968_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.969_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.970_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.971_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.972_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.973_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.974_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.975_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.976_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.977_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.978_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.979_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.980_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.981_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.982_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.983_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.984_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.985_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.986_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.987_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.988_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.989_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.990_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.991_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.992_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.993_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.994_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.995_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.996_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.997_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.998_3389.root.h5 163
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.999_3389.root.h5 163
# Time spent in _create_attrs: 12.847454071044922 s
# Time spent in build_dataset: 842.3093371391296 s

# %% [markdown]
# ## General plots about S1 and S2 (no selections applied)

# %%
data = full

# %% [markdown]
# #### Number of S1 and S2 signals

# %%
pdf(data.nS1, 10, range=(0, 10))
labels("# S1", "Entries")
save("NS1")

################################
pdf(data.nS2,  5, range=(0, 5))
labels("# S2", "Entries")
save("NS2")

# %% [markdown]
# <b>
# 1. With the current configuration, the probability of having more than one S2 if ~20%.
#
# 2. On the other hand, the ratio of events with exactly one S1 is ~60%
# </b>

# %% [markdown]
# ## From now on the study is focused on those events with exactly one S1 and one S2

# %%
oneS1oneS2 = full[full.ok]
data = oneS1oneS2
print("Full set   :", full.evts.size, "events")
print("Reduced set:", data.evts.size, "events")
print("Ratio      :", data.evts.size/full.evts.size)
# Out:
# Time spent in _create_attrs: 8.949890851974487 s
# Full set   : 488511 events
# Reduced set: 264291 events
# Ratio      : 0.5410134060440809

# %% [markdown]
# <b>
# The ratio of "reliable" to total events is ~51.3%
# </b>

# %% [markdown]
# # Distribution of events in Z

# %%
hist(flat(data.Z), 100, (0, 600))
labels("Drift time ($\mu$s)", "Entries")

# %% [markdown]
# <b>
# Looks like there is an accumulation of events for Z < 200 $\mu$s and a flat distribution for Z > 200 $\mu$s.
# </b>

# %% [markdown]
# # Comparison between Z < 250 and Z > 250

# %%
closeToAnode   = oneS1oneS2[flat(oneS1oneS2.Z < 250)]
closeToCathode = oneS1oneS2[flat(oneS1oneS2.Z > 250)]

z_anode     = flat(closeToAnode.Z)
z_cathode   = flat(closeToCathode.Z)

lbls = ["Anode", "Cathode"]
# Out:
# Time spent in _create_attrs: 10.233490943908691 s
# Time spent in _create_attrs: 0.37149500846862793 s

# %% [markdown]
# # S1

# %%
s1w_anode   = flat(closeToAnode.S1w)
s1w_cathode = flat(closeToCathode.S1w)

################################
doublehist(s1w_anode, s1w_cathode, lbls, 20, range=(0, 500))
labels("S1 width (ns)", "Entries")
save("S1width")

################################
doublescatter(z_anode, s1w_anode, z_cathode, s1w_cathode, lbls)
x, y, _ = fitf.profileX(z_anode, s1w_anode, 30)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1w_cathode, 30)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 width (ns)")
save("S1widthvsZ")

# %%
s1h_anode   = flat(closeToAnode.S1h)
s1h_cathode = flat(closeToCathode.S1h)

ylim = 0, 30
################################
doublehist(s1h_anode, s1h_cathode, lbls, 40, range=ylim, log=True)
labels("S1 height (pes)", "Entries")
save("S1height")

################################
doublescatter(z_anode, s1h_anode, z_cathode, s1h_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s1h_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1h_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 height (pes)")
save("S1heightvsZ")

# %%
s1i_anode   = flat(closeToAnode.S1i)
s1i_cathode = flat(closeToCathode.S1i)

ylim = 0, 30
################################
doublehist(s1i_anode, s1i_cathode, lbls, 40, range=ylim)
labels("S1 energy (pes)", "Entries")
save("S1energy")

################################
doublescatter(z_anode, s1i_anode, z_cathode, s1i_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s1i_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1i_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 energy (pes)")
save("S1energyvsZ")

# %%
S1_ratio_anode   = s1h_anode/s1i_anode
S1_ratio_cathode = s1h_cathode/s1i_cathode

################################
doublehist(S1_ratio_anode, S1_ratio_cathode, lbls, 40)
labels("Peak to area ratio", "Entries")
save("S1peak2area")

# %% [markdown]
# # S2

# %%
s2w_anode   = flat(closeToAnode.S2w)
s2w_cathode = flat(closeToCathode.S2w)

################################
doublehist(s2w_anode, s2w_cathode, lbls, 20, range=(0, 20))
labels("S2 width ($\mu$s)", "Entries")
save("S2width")

################################
doublescatter(z_anode, s2w_anode, z_cathode, s2w_cathode, lbls)
x, y, _ = fitf.profileX(z_anode, s2w_anode, 30)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2w_cathode, 30)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 width ($\mu$s)")
save("S2widthvsZ")

# %%
s2h_anode   = flat(closeToAnode.S2h)
s2h_cathode = flat(closeToCathode.S2h)

ylim = 0, 6e3
################################
doublehist(s2h_anode, s2h_cathode, lbls, 40, range=ylim)
labels("S2 height (pes)", "Entries")
save("S2height")

################################
doublescatter(z_anode, s2h_anode, z_cathode, s2h_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s2h_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2h_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 height (pes)")
save("S2heightvsZ")

# %%
s2i_anode   = flat(closeToAnode.S2i)
s2i_cathode = flat(closeToCathode.S2i)

ylim = 3e3, 10e3
################################
doublehist(s2i_anode, s2i_cathode, lbls, 80, range=ylim)
labels("S2 energy (pes)", "Entries")
save("S2energy")

################################
doublescatter(z_anode, s2i_anode, z_cathode, s2i_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s2i_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2i_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 energy (pes)")
save("S2energyvsZ")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
S2_ratio_anode   = s2h_anode/s2i_anode
S2_ratio_cathode = s2h_cathode/s2i_cathode

################################
doublehist(S2_ratio_anode, S2_ratio_cathode, lbls, 50, range=(0.1, 0.5))
labels("Peak to area ratio", "Entries")
save("S2peak2area")

# %%
doublescatter(s1i_anode, s2i_anode, s1i_cathode, s2i_cathode, lbls)
xlim = 0, 30
ylim = 3e3, 12e3
plt.xlim(xlim)
plt.ylim(ylim)
x, y, _ = fitf.profileX(s1i_anode, s2i_anode, 30, xrange=xlim, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(s1i_cathode, s2i_cathode, 30, xrange=xlim, yrange=ylim)
plt.plot(x, y, profOpt)
labels("S1 energy (pes)", "S2 energy (pes)")
save("S2vsS1")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Further selections: S1width < 160 ns

# %%
closeToAnodeShortS1   = closeToAnode[flat(closeToAnode.S1w < 160)]
closeToCathodeShortS1 = closeToCathode[flat(closeToCathode.S1w < 160)]

z_anode   = flat(closeToAnodeShortS1.Z)
z_cathode = flat(closeToCathodeShortS1.Z)

lbls = ["Anode", "Cathode"]
# Out:
# Time spent in _create_attrs: 7.245093107223511 s
# Time spent in _create_attrs: 0.2317979335784912 s

# %% [markdown]
# # S1

# %%
s1w_anode   = flat(closeToAnodeShortS1.S1w)
s1w_cathode = flat(closeToCathodeShortS1.S1w)

################################
doublehist(s1w_anode, s1w_cathode, lbls, 20, range=(0, 500))
labels("S1 width (ns)", "Entries")
save("S1width")

################################
doublescatter(z_anode, s1w_anode, z_cathode, s1w_cathode, lbls)
x, y, _ = fitf.profileX(z_anode, s1w_anode, 30)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1w_cathode, 30)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 width (ns)")
save("S1widthvsZ")

# %%
s1h_anode   = flat(closeToAnodeShortS1.S1h)
s1h_cathode = flat(closeToCathodeShortS1.S1h)

ylim = 0, 30
################################
doublehist(s1h_anode, s1h_cathode, lbls, 40, range=ylim, log=True)
labels("S1 height (pes)", "Entries")
save("S1height")

################################
doublescatter(z_anode, s1h_anode, z_cathode, s1h_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s1h_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1h_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 height (pes)")
save("S1heightvsZ")

# %%
s1i_anode   = flat(closeToAnodeShortS1.S1i)
s1i_cathode = flat(closeToCathodeShortS1.S1i)

ylim = 0, 30
################################
doublehist(s1i_anode, s1i_cathode, lbls, 40, range=ylim)
labels("S1 energy (pes)", "Entries")
save("S1energy")

################################
doublescatter(z_anode, s1i_anode, z_cathode, s1i_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s1i_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1i_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 energy (pes)")
save("S1energyvsZ")

# %%
S1_ratio_anode   = s1h_anode/s1i_anode
S1_ratio_cathode = s1h_cathode/s1i_cathode

################################
doublehist(S1_ratio_anode, S1_ratio_cathode, lbls, 40)
labels("Peak to area ratio", "Entries")
save("S1peak2area")

# %% [markdown]
# # S2

# %%
s2w_anode   = flat(closeToAnodeShortS1.S2w)
s2w_cathode = flat(closeToCathodeShortS1.S2w)

################################
doublehist(s2w_anode, s2w_cathode, lbls, 20, range=(0, 20))
labels("S2 width ($\mu$s)", "Entries")
save("S2width")

################################
doublescatter(z_anode, s2w_anode, z_cathode, s2w_cathode, lbls)
x, y, _ = fitf.profileX(z_anode, s2w_anode, 30)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2w_cathode, 30)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 width ($\mu$s)")
save("S2widthvsZ")

# %%
s2h_anode   = flat(closeToAnodeShortS1.S2h)
s2h_cathode = flat(closeToCathodeShortS1.S2h)

ylim = 0, 6e3
################################
doublehist(s2h_anode, s2h_cathode, lbls, 40, range=ylim)
labels("S2 height (pes)", "Entries")
save("S2height")

################################
doublescatter(z_anode, s2h_anode, z_cathode, s2h_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s2h_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2h_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 height (pes)")
save("S2heightvsZ")

# %%
s2i_anode   = flat(closeToAnodeShortS1.S2i)
s2i_cathode = flat(closeToCathodeShortS1.S2i)

ylim = 3e3, 10e3
################################
doublehist(s2i_anode, s2i_cathode, lbls, 80, range=ylim)
labels("S2 energy (pes)", "Entries")
save("S2energy")

################################
doublescatter(z_anode, s2i_anode, z_cathode, s2i_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s2i_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2i_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 energy (pes)")
save("S2energyvsZ")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
S2_ratio_anode   = s2h_anode/s2i_anode
S2_ratio_cathode = s2h_cathode/s2i_cathode

################################
doublehist(S2_ratio_anode, S2_ratio_cathode, lbls, 50, range=(0.1, 0.5))
labels("Peak to area ratio", "Entries")
save("S2peak2area")

# %%
doublescatter(s1i_anode, s2i_anode, s1i_cathode, s2i_cathode, lbls)
xlim = 0, 30
ylim = 3e3, 12e3
plt.xlim(xlim)
plt.ylim(ylim)
x, y, _ = fitf.profileX(s1i_anode, s2i_anode, 30, xrange=xlim, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(s1i_cathode, s2i_cathode, 30, xrange=xlim, yrange=ylim)
plt.plot(x, y, profOpt)
labels("S1 energy (pes)", "S2 energy (pes)")
save("S2vsS1")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Further selections: S1height < 5 pes

# %%
closeToAnodeShortTinyS1   = closeToAnodeShortS1[flat(closeToAnodeShortS1.S1h < 5)]
closeToCathodeShortTinyS1 = closeToCathodeShortS1[flat(closeToCathodeShortS1.S1h < 5)]

z_anode   = flat(closeToAnodeShortTinyS1.Z)
z_cathode = flat(closeToCathodeShortTinyS1.Z)

lbls = ["Anode", "Cathode"]
# Out:
# Time spent in _create_attrs: 4.281231880187988 s
# Time spent in _create_attrs: 0.1423358917236328 s

# %% [markdown]
# # S1

# %%
s1w_anode   = flat(closeToAnodeShortTinyS1.S1w)
s1w_cathode = flat(closeToCathodeShortTinyS1.S1w)

################################
doublehist(s1w_anode, s1w_cathode, lbls, 20, range=(0, 500))
labels("S1 width (ns)", "Entries")
save("S1width")

################################
doublescatter(z_anode, s1w_anode, z_cathode, s1w_cathode, lbls)
x, y, _ = fitf.profileX(z_anode, s1w_anode, 30)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1w_cathode, 30)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 width (ns)")
save("S1widthvsZ")

# %%
s1h_anode   = flat(closeToAnodeShortTinyS1.S1h)
s1h_cathode = flat(closeToCathodeShortTinyS1.S1h)

ylim = 0, 10
################################
doublehist(s1h_anode, s1h_cathode, lbls, 40, range=ylim, log=True)
labels("S1 height (pes)", "Entries")
save("S1height")

################################
doublescatter(z_anode, s1h_anode, z_cathode, s1h_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s1h_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1h_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 height (pes)")
save("S1heightvsZ")

# %%
s1i_anode   = flat(closeToAnodeShortTinyS1.S1i)
s1i_cathode = flat(closeToCathodeShortTinyS1.S1i)

ylim = 0, 30
################################
doublehist(s1i_anode, s1i_cathode, lbls, 40, range=ylim)
labels("S1 energy (pes)", "Entries")
save("S1energy")

################################
doublescatter(z_anode, s1i_anode, z_cathode, s1i_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s1i_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1i_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 energy (pes)")
save("S1energyvsZ")

# %%
S1_ratio_anode   = s1h_anode/s1i_anode
S1_ratio_cathode = s1h_cathode/s1i_cathode

################################
doublehist(S1_ratio_anode, S1_ratio_cathode, lbls, 40)
labels("Peak to area ratio", "Entries")
save("S1peak2area")

# %% [markdown]
# # S2

# %%
s2w_anode   = flat(closeToAnodeShortTinyS1.S2w)
s2w_cathode = flat(closeToCathodeShortTinyS1.S2w)

################################
doublehist(s2w_anode, s2w_cathode, lbls, 20, range=(0, 20))
labels("S2 width ($\mu$s)", "Entries")
save("S2width")

################################
doublescatter(z_anode, s2w_anode, z_cathode, s2w_cathode, lbls)
x, y, _ = fitf.profileX(z_anode, s2w_anode, 30)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2w_cathode, 30)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 width ($\mu$s)")
save("S2widthvsZ")

# %%
s2h_anode   = flat(closeToAnodeShortTinyS1.S2h)
s2h_cathode = flat(closeToCathodeShortTinyS1.S2h)

ylim = 0, 6e3
################################
doublehist(s2h_anode, s2h_cathode, lbls, 40, range=ylim)
labels("S2 height (pes)", "Entries")
save("S2height")

################################
doublescatter(z_anode, s2h_anode, z_cathode, s2h_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s2h_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2h_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 height (pes)")
save("S2heightvsZ")

# %%
s2i_anode   = flat(closeToAnodeShortTinyS1.S2i)
s2i_cathode = flat(closeToCathodeShortTinyS1.S2i)

ylim = 3e3, 10e3
################################
doublehist(s2i_anode, s2i_cathode, lbls, 50, range=ylim)
labels("S2 energy (pes)", "Entries")
save("S2energy")

################################
doublescatter(z_anode, s2i_anode, z_cathode, s2i_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s2i_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2i_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 energy (pes)")
save("S2energyvsZ")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
S2_ratio_anode   = s2h_anode/s2i_anode
S2_ratio_cathode = s2h_cathode/s2i_cathode

################################
doublehist(S2_ratio_anode, S2_ratio_cathode, lbls, 50, range=(0.1, 0.5))
labels("Peak to area ratio", "Entries")
save("S2peak2area")

# %%
doublescatter(s1i_anode, s2i_anode, s1i_cathode, s2i_cathode, lbls)
xlim = 0, 30
ylim = 3e3, 12e3
plt.xlim(xlim)
plt.ylim(ylim)
x, y, _ = fitf.profileX(s1i_anode, s2i_anode, 30, xrange=xlim, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(s1i_cathode, s2i_cathode, 30, xrange=xlim, yrange=ylim)
plt.plot(x, y, profOpt)
labels("S1 energy (pes)", "S2 energy (pes)")
save("S2vsS1")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Take small peak to area ratio in S1

# %%
#closeToAnodeShortTinyS1SmallP2A   = closeToAnodeShortTinyS1[(flat(closeToAnodeShortTinyS1.S1h)/flat(closeToAnodeShortTinyS1.S1i) > 0.25) & (flat(closeToAnodeShortTinyS1.S1h)/flat(closeToAnodeShortTinyS1.S1i) < 0.27)]
#closeToCathodeShortTinyS1SmallP2A = closeToCathodeShortTinyS1[(flat(closeToCathodeShortTinyS1.S1h)/flat(closeToCathodeShortTinyS1.S1i) > 0.25) & (flat(closeToCathodeShortTinyS1.S1h)/flat(closeToCathodeShortTinyS1.S1i) < 0.27)]

closeToAnodeShortTinyS1SmallP2A   = closeToAnodeShortTinyS1[flat(closeToAnodeShortTinyS1.S1h)/flat(closeToAnodeShortTinyS1.S1i) < 0.25]
closeToCathodeShortTinyS1SmallP2A = closeToCathodeShortTinyS1[flat(closeToCathodeShortTinyS1.S1h)/flat(closeToCathodeShortTinyS1.S1i) < 0.25]

z_anode   = flat(closeToAnodeShortTinyS1SmallP2A.Z)
z_cathode = flat(closeToCathodeShortTinyS1SmallP2A.Z)

lbls = ["Anode", "Cathode"]
# Out:
# Time spent in _create_attrs: 4.61133885383606 s
# Time spent in _create_attrs: 0.043142080307006836 s

# %% [markdown]
# # S1

# %%
s1w_anode   = flat(closeToAnodeShortTinyS1SmallP2A.S1w)
s1w_cathode = flat(closeToCathodeShortTinyS1SmallP2A.S1w)

################################
doublehist(s1w_anode, s1w_cathode, lbls, 20, range=(0, 500))
labels("S1 width (ns)", "Entries")
save("S1width")

################################
doublescatter(z_anode, s1w_anode, z_cathode, s1w_cathode, lbls)
x, y, _ = fitf.profileX(z_anode, s1w_anode, 30)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1w_cathode, 30)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 width (ns)")
save("S1widthvsZ")

# %%
s1h_anode   = flat(closeToAnodeShortTinyS1SmallP2A.S1h)
s1h_cathode = flat(closeToCathodeShortTinyS1SmallP2A.S1h)

ylim = 0, 10
################################
doublehist(s1h_anode, s1h_cathode, lbls, 40, range=ylim, log=True)
labels("S1 height (pes)", "Entries")
save("S1height")

################################
doublescatter(z_anode, s1h_anode, z_cathode, s1h_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s1h_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1h_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 height (pes)")
save("S1heightvsZ")

# %%
s1i_anode   = flat(closeToAnodeShortTinyS1SmallP2A.S1i)
s1i_cathode = flat(closeToCathodeShortTinyS1SmallP2A.S1i)

ylim = 0, 30
################################
doublehist(s1i_anode, s1i_cathode, lbls, 40, range=ylim)
labels("S1 energy (pes)", "Entries")
save("S1energy")

################################
doublescatter(z_anode, s1i_anode, z_cathode, s1i_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s1i_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1i_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 energy (pes)")
save("S1energyvsZ")

# %%
S1_ratio_anode   = s1h_anode/s1i_anode
S1_ratio_cathode = s1h_cathode/s1i_cathode

################################
doublehist(S1_ratio_anode, S1_ratio_cathode, lbls, 40)
labels("Peak to area ratio", "Entries")
save("S1peak2area")

# %% [markdown]
# # S2

# %%
s2w_anode   = flat(closeToAnodeShortTinyS1SmallP2A.S2w)
s2w_cathode = flat(closeToCathodeShortTinyS1SmallP2A.S2w)

################################
doublehist(s2w_anode, s2w_cathode, lbls, 20, range=(0, 20))
labels("S2 width ($\mu$s)", "Entries")
save("S2width")

################################
doublescatter(z_anode, s2w_anode, z_cathode, s2w_cathode, lbls)
x, y, _ = fitf.profileX(z_anode, s2w_anode, 30)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2w_cathode, 30)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 width ($\mu$s)")
save("S2widthvsZ")

# %%
s2h_anode   = flat(closeToAnodeShortTinyS1SmallP2A.S2h)
s2h_cathode = flat(closeToCathodeShortTinyS1SmallP2A.S2h)

ylim = 0, 6e3
################################
doublehist(s2h_anode, s2h_cathode, lbls, 40, range=ylim)
labels("S2 height (pes)", "Entries")
save("S2height")

################################
doublescatter(z_anode, s2h_anode, z_cathode, s2h_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s2h_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2h_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 height (pes)")
save("S2heightvsZ")

# %%
s2i_anode   = flat(closeToAnodeShortTinyS1SmallP2A.S2i)
s2i_cathode = flat(closeToCathodeShortTinyS1SmallP2A.S2i)

ylim = 3e3, 10e3
################################
doublehist(s2i_anode, s2i_cathode, lbls, 40, range=ylim)
labels("S2 energy (pes)", "Entries")
save("S2energy")

################################
doublescatter(z_anode, s2i_anode, z_cathode, s2i_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s2i_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2i_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 energy (pes)")
save("S2energyvsZ")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
S2_ratio_anode   = s2h_anode/s2i_anode
S2_ratio_cathode = s2h_cathode/s2i_cathode

################################
doublehist(S2_ratio_anode, S2_ratio_cathode, lbls, 50, range=(0.1, 0.5))
labels("Peak to area ratio", "Entries")
save("S2peak2area")

# %%
doublescatter(s1i_anode, s2i_anode, s1i_cathode, s2i_cathode, lbls)
xlim = 0, 30
ylim = 3e3, 12e3
plt.xlim(xlim)
plt.ylim(ylim)
x, y, _ = fitf.profileX(s1i_anode, s2i_anode, 30, xrange=xlim, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(s1i_cathode, s2i_cathode, 30, xrange=xlim, yrange=ylim)
plt.plot(x, y, profOpt)
labels("S1 energy (pes)", "S2 energy (pes)")
save("S2vsS1")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Take low S1 energy (< 7 pes)

# %%
closeToAnodeShortTinyS1SmallP2ALow   = closeToAnodeShortTinyS1SmallP2A[flat(closeToAnodeShortTinyS1SmallP2A.S1i) < 6]
closeToCathodeShortTinyS1SmallP2ALow = closeToCathodeShortTinyS1SmallP2A[flat(closeToCathodeShortTinyS1SmallP2A.S1i) < 6]

z_anode   = flat(closeToAnodeShortTinyS1SmallP2ALow.Z)
z_cathode = flat(closeToCathodeShortTinyS1SmallP2ALow.Z)

lbls = ["Anode", "Cathode"]
# Out:
# Time spent in _create_attrs: 1.160269021987915 s
# Time spent in _create_attrs: 0.03402304649353027 s

# %% [markdown]
# # S1

# %%
s1w_anode   = flat(closeToAnodeShortTinyS1SmallP2ALow.S1w)
s1w_cathode = flat(closeToCathodeShortTinyS1SmallP2ALow.S1w)

################################
doublehist(s1w_anode, s1w_cathode, lbls, 20, range=(0, 500))
labels("S1 width (ns)", "Entries")
save("S1width")

################################
doublescatter(z_anode, s1w_anode, z_cathode, s1w_cathode, lbls)
x, y, _ = fitf.profileX(z_anode, s1w_anode, 30)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1w_cathode, 30)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 width (ns)")
save("S1widthvsZ")

# %%
s1h_anode   = flat(closeToAnodeShortTinyS1SmallP2ALow.S1h)
s1h_cathode = flat(closeToCathodeShortTinyS1SmallP2ALow.S1h)

ylim = 0, 10
################################
doublehist(s1h_anode, s1h_cathode, lbls, 40, range=ylim, log=True)
labels("S1 height (pes)", "Entries")
save("S1height")

################################
doublescatter(z_anode, s1h_anode, z_cathode, s1h_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s1h_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1h_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 height (pes)")
save("S1heightvsZ")

# %%
s1i_anode   = flat(closeToAnodeShortTinyS1SmallP2ALow.S1i)
s1i_cathode = flat(closeToCathodeShortTinyS1SmallP2ALow.S1i)

ylim = 0, 30
################################
doublehist(s1i_anode, s1i_cathode, lbls, 40, range=ylim)
labels("S1 energy (pes)", "Entries")
save("S1energy")

################################
doublescatter(z_anode, s1i_anode, z_cathode, s1i_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s1i_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s1i_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S1 energy (pes)")
save("S1energyvsZ")

# %%
S1_ratio_anode   = s1h_anode/s1i_anode
S1_ratio_cathode = s1h_cathode/s1i_cathode

################################
doublehist(S1_ratio_anode, S1_ratio_cathode, lbls, 40)
labels("Peak to area ratio", "Entries")
save("S1peak2area")

# %% [markdown]
# # S2

# %%
s2w_anode   = flat(closeToAnodeShortTinyS1SmallP2ALow.S2w)
s2w_cathode = flat(closeToCathodeShortTinyS1SmallP2ALow.S2w)

################################
doublehist(s2w_anode, s2w_cathode, lbls, 20, range=(0, 20))
labels("S2 width ($\mu$s)", "Entries")
save("S2width")

################################
doublescatter(z_anode, s2w_anode, z_cathode, s2w_cathode, lbls)
x, y, _ = fitf.profileX(z_anode, s2w_anode, 30)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2w_cathode, 30)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 width ($\mu$s)")
save("S2widthvsZ")

# %%
s2h_anode   = flat(closeToAnodeShortTinyS1SmallP2ALow.S2h)
s2h_cathode = flat(closeToCathodeShortTinyS1SmallP2ALow.S2h)

ylim = 0, 6e3
################################
doublehist(s2h_anode, s2h_cathode, lbls, 40, range=ylim)
labels("S2 height (pes)", "Entries")
save("S2height")

################################
doublescatter(z_anode, s2h_anode, z_cathode, s2h_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s2h_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2h_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 height (pes)")
save("S2heightvsZ")

# %%
s2i_anode   = flat(closeToAnodeShortTinyS1SmallP2ALow.S2i)
s2i_cathode = flat(closeToCathodeShortTinyS1SmallP2ALow.S2i)

ylim = 3e3, 10e3
################################
doublehist(s2i_anode, s2i_cathode, lbls, 50, range=ylim)
labels("S2 energy (pes)", "Entries")
save("S2energy")

################################
doublescatter(z_anode, s2i_anode, z_cathode, s2i_cathode, lbls)
plt.ylim(ylim)
x, y, _ = fitf.profileX(z_anode, s2i_anode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(z_cathode, s2i_cathode, 30, yrange=ylim)
plt.plot(x, y, profOpt)
labels("Drift time ($\mu$s)", "S2 energy (pes)")
save("S2energyvsZ")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
S2_ratio_anode   = s2h_anode/s2i_anode
S2_ratio_cathode = s2h_cathode/s2i_cathode

################################
doublehist(S2_ratio_anode, S2_ratio_cathode, lbls, 50, range=(0.1, 0.5))
labels("Peak to area ratio", "Entries")
save("S2peak2area")

# %%
doublescatter(s1i_anode, s2i_anode, s1i_cathode, s2i_cathode, lbls)
xlim = 0, 30
ylim = 3e3, 12e3
plt.xlim(xlim)
plt.ylim(ylim)
x, y, _ = fitf.profileX(s1i_anode, s2i_anode, 30, xrange=xlim, yrange=ylim)
plt.plot(x, y, profOpt)
x, y, _ = fitf.profileX(s1i_cathode, s2i_cathode, 30, xrange=xlim, yrange=ylim)
plt.plot(x, y, profOpt)
labels("S1 energy (pes)", "S2 energy (pes)")
save("S2vsS1")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
