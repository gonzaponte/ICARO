# %% [markdown]
# # Kr analysis (MC)

# %%
from __future__ import print_function, division

import os
import operator
import functools
import copy
import time
import glob
print("Running on ", time.asctime())

import numpy as np
import tables as tb
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib inline

import invisible_cities.database.load_db as DB
import invisible_cities.core.system_of_units_c as SystemOfUnits
import invisible_cities.reco.pmaps_functions as pmapf
import invisible_cities.core.fit_functions as fitf

DataPMT = DB.DataPMT()
DataSiPM = DB.DataSiPM()
units = SystemOfUnits.SystemOfUnits()
pi = np.pi
# Out:
# Running on  Mon Mar 27 19:20:24 2017

# %% [markdown]
# #### General plotting options

# %%
plt.rcParams["figure.figsize"]          = 8, 6
plt.rcParams["font.size"]               = 15
plt.rcParams["figure.max_open_warning"] = 100

profOpt = "--k"
fitOpt  = "r"

outputfolder = "plots/cut3.5"
if not os.path.exists(outputfolder):
    os.mkdir(outputfolder)

# %% [markdown]
# #### Useful functions

# %%
def width(times, to_mus=False):
    """
    Compute peak width.
    """
    w = (np.max(times) - np.min(times)) if np.any(times) else 0.
    return w * units.ns/units.mus if to_mus else w


def timefunc(f):
    """
    Decorator for function timing.
    """
    def time_f(*args, **kwargs):
        t0 = time.time()
        output = f(*args, **kwargs)
        print("Time spent in {}: {} s".format(f.__name__,
                                              time.time() - t0))
        return output
    return time_f


def integrate_charge(d):
    """
    Integrate charge from a SiPM dictionary.
    """
    newd = dict((key, np.sum(value)) for key, value in d.items())
    return map(np.array, list(zip(*newd.items())))


def flat(nested_list):
    while hasattr(nested_list[0], "__iter__"):
        nested_list = [item for inner_list in nested_list for item in inner_list]
    return np.array(nested_list)


def labels(xlabel, ylabel):
    """
    Set x and y labels.
    """
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)


def hist(*args, **kwargs):
    """
    Create a figure and then the histogram
    """
    plt.figure()
    return plt.hist(*args, **kwargs)

    
def hist2d(*args, **kwargs):
    """
    Create a figure and then the histogram
    """
    plt.figure()
    return plt.hist2d(*args, **kwargs)

    
def pdf(data, *args, **kwargs):
    """
    Create a normalized histogram with appropiate range.
    """
    data = np.array(data)
    h = hist(data, *args, **kwargs, weights=np.ones_like(data)/len(data))
    plt.yscale("log")
    plt.ylim(1e-4, 1.)
    return h
    
def scatter(*args, **kwargs):
    """
    Create a figure and then a scatter plot
    """
    plt.figure()
    return plt.scatter(*args, **kwargs)


def save_to_folder(outputfolder, name):
    """
    Set title and save plot in folder.
    """
    plt.title(name)
    plt.savefig("{}/{}.png".format(outputfolder, name), dpi=100)

save = functools.partial(save_to_folder, outputfolder)

# %% [markdown]
# ### Input data

# %%
# Comment out this line if your data is in $IC_DATA
os.environ["IC_DATA"] = os.environ["IC_DATA"] + "/Kr2016/data/3389/"

pattern = "$IC_DATA/pmaps_waves.gdcsnext.*_3389.root.h5"
ifiles  = glob.glob(os.path.expandvars(pattern))
for i in reversed(range(len(ifiles))):
    ifile = ifiles[i]
    try:
        tb.open_file(ifile).close()
    except:
        del ifiles[i]
        print("deleting", ifile)
print("# files:", len(ifiles))

# %% [markdown]
# ### Define event class

# %%
class Event:
    """
    Store for relevant event info.
    """
    def __init__(self):
        self.nS1   = 0
        self.S1w   = []
        self.S1h   = []
        self.S1i   = []
        self.S1t   = []

        self.nS2   = 0
        self.S2w   = []
        self.S2h   = []
        self.S2i   = []

        self.Nsipm = []
        self.Q     = []
        self.Qsipm = []
        self.Xt    = np.nan
        self.Yt    = np.nan
        self.X     = np.nan
        self.Y     = np.nan
        self.Xrms  = np.nan
        self.Yrms  = np.nan
        self.Z     = np.nan
        self.R     = np.nan
        self.Phi   = np.nan

        self.ok    = False

# %% [markdown]
# ### Define dataset class

# %%
class Dataset:
    """
    Trick for accesing event properties as an attribute of the dataset.
    """
    def __init__(self, evts):
        self.evts = np.array(evts, dtype=object)
        self._create_attrs()
    
    @timefunc
    def _create_attrs(self):
        for attr in filter(lambda x: not x.endswith("__"), Event().__dict__):
            setattr(self, attr, np.array([getattr(evt, attr) for evt in self.evts]))

    def __getitem__(self, sel):
        return Dataset(self.evts[sel])

# %% [markdown]
# ## Functions to fill the event and dataset classes

# %%
@timefunc
def fill_evts(s1s, s2s, sis, evts_out, ifile=None):    
    evts = set(list(s1s.keys()) +
               list(s2s.keys()) +
               list(sis.keys()))
    nevt = len(evts)
    print(ifile, nevt)
    for i, evt_number in enumerate(evts):
        evt = Event()
        s1  = s1s.get(evt_number, dict())
        s2  = s2s.get(evt_number, dict())
        si  = sis.get(evt_number, dict())
        
        evt.nS1 = 0
        evt.nS2 = len(s2)

        s1time = 0
        for peak, (t, e) in s1.items():
            sel  = e > 0.5
            t, e = t[sel], e[sel]
            if t.size < 5:
                continue
            evt.nS1 += 1
            evt.S1w.append(width(t))
            evt.S1h.append(np.max(e))
            evt.S1i.append(np.sum(e))
            s1time = t[np.argmax(e)]
            evt.S1t.append(s1time)
        
        s2time = 0
        for peak, (t, e) in s2.items():
            evt.S2w.append(width(t, to_mus=True))
            evt.S2h.append(np.max(e))
            evt.S2i.append(np.sum(e))
            s2time = t[np.argmax(e)]

            IDs, Qs = integrate_charge(si[peak]) if peak in si else ([], [])
            Qpeak   = np.sum(Qs)
            xsipms  = DataSiPM.X.values[IDs]
            ysipms  = DataSiPM.Y.values[IDs]

            evt.Qsipm.append(Qs)
            evt.Nsipm.append(len(IDs))
            evt.Q    .append(Qpeak)
            evt.X    = np.average(xsipms, weights=Qs) if np.any(Qs) else np.nan
            evt.Y    = np.average(ysipms, weights=Qs) if np.any(Qs) else np.nan
            evt.Xrms = (np.sum(Qs * (xsipms-evt.X)**2) / (Qpeak - 1))**0.5 if np.any(Qs) else np.nan
            evt.Yrms = (np.sum(Qs * (ysipms-evt.Y)**2) / (Qpeak - 1))**0.5 if np.any(Qs) else np.nan
            evt.R    = (evt.X**2 + evt.Y**2)**0.5 if np.any(Qs) else np.nan
            evt.Phi  = np.arctan2(evt.Y, evt.X) if np.any(Qs) else np.nan

        evt.ok = evt.nS1 == evt.nS2 == 1
        if evt.ok:
            evt.Z = (s2time - s1time) * units.ns / units.mus
        evts_out.append(evt)


@timefunc
def build_dataset(inputfiles):
    evts_out = []
    for ifile in inputfiles:
        s1s, s2s, sis = pmapf.read_pmaps(ifile)
        fill_evts(pmapf.df_to_pmaps_dict(s1s),
                  pmapf.df_to_pmaps_dict(s2s),
                  pmapf.df_to_s2si_dict (sis),
                  evts_out, ifile)
    return Dataset(evts_out)

# %% [markdown]
# # Read data

# %%
full = build_dataset(ifiles)
# Out:
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.000_3389.root.h5 163
# Time spent in fill_evts: 0.06818914413452148 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.001_3389.root.h5 163
# Time spent in fill_evts: 0.061810970306396484 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.002_3389.root.h5 163
# Time spent in fill_evts: 0.06792998313903809 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.003_3389.root.h5 163
# Time spent in fill_evts: 0.0983438491821289 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.004_3389.root.h5 163
# Time spent in fill_evts: 0.0678110122680664 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.005_3389.root.h5 163
# Time spent in fill_evts: 0.07445311546325684 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.006_3389.root.h5 163
# Time spent in fill_evts: 0.08080196380615234 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.007_3389.root.h5 163
# Time spent in fill_evts: 0.1468660831451416 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.008_3389.root.h5 163
# Time spent in fill_evts: 0.08090400695800781 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.009_3389.root.h5 163
# Time spent in fill_evts: 0.09281516075134277 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.010_3389.root.h5 163
# Time spent in fill_evts: 0.09601712226867676 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.011_3389.root.h5 163
# Time spent in fill_evts: 0.1000819206237793 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.012_3389.root.h5 163
# Time spent in fill_evts: 0.11546087265014648 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.013_3389.root.h5 163
# Time spent in fill_evts: 0.12124490737915039 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.014_3389.root.h5 163
# Time spent in fill_evts: 0.11591792106628418 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.015_3389.root.h5 163
# Time spent in fill_evts: 0.10307121276855469 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.016_3389.root.h5 163
# Time spent in fill_evts: 0.06878900527954102 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.017_3389.root.h5 163
# Time spent in fill_evts: 0.07661700248718262 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.018_3389.root.h5 163
# Time spent in fill_evts: 0.09192919731140137 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.019_3389.root.h5 163
# Time spent in fill_evts: 0.10795402526855469 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.020_3389.root.h5 163
# Time spent in fill_evts: 0.06976103782653809 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.021_3389.root.h5 163
# Time spent in fill_evts: 0.06669497489929199 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.022_3389.root.h5 163
# Time spent in fill_evts: 0.06560707092285156 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.023_3389.root.h5 163
# Time spent in fill_evts: 0.06997799873352051 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.024_3389.root.h5 163
# Time spent in fill_evts: 0.07510900497436523 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.025_3389.root.h5 163
# Time spent in fill_evts: 0.11020803451538086 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.026_3389.root.h5 163
# Time spent in fill_evts: 0.09097814559936523 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.027_3389.root.h5 163
# Time spent in fill_evts: 0.09601879119873047 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.028_3389.root.h5 163
# Time spent in fill_evts: 0.09546494483947754 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.029_3389.root.h5 163
# Time spent in fill_evts: 0.11793398857116699 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.030_3389.root.h5 163
# Time spent in fill_evts: 0.07036709785461426 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.031_3389.root.h5 163
# Time spent in fill_evts: 0.07615494728088379 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.032_3389.root.h5 163
# Time spent in fill_evts: 0.08162498474121094 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.033_3389.root.h5 163
# Time spent in fill_evts: 0.07701802253723145 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.034_3389.root.h5 163
# Time spent in fill_evts: 0.06687283515930176 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.035_3389.root.h5 163
# Time spent in fill_evts: 0.06441092491149902 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.036_3389.root.h5 163
# Time spent in fill_evts: 0.11182713508605957 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.037_3389.root.h5 163
# Time spent in fill_evts: 0.08249592781066895 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.038_3389.root.h5 163
# Time spent in fill_evts: 0.05831789970397949 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.039_3389.root.h5 163
# Time spent in fill_evts: 0.08594179153442383 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.040_3389.root.h5 163
# Time spent in fill_evts: 0.09853816032409668 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.041_3389.root.h5 163
# Time spent in fill_evts: 0.08787178993225098 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.042_3389.root.h5 163
# Time spent in fill_evts: 0.08609509468078613 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.043_3389.root.h5 163
# Time spent in fill_evts: 0.17894506454467773 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.044_3389.root.h5 163
# Time spent in fill_evts: 0.10912013053894043 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.045_3389.root.h5 163
# Time spent in fill_evts: 0.11545395851135254 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.046_3389.root.h5 163
# Time spent in fill_evts: 0.09375214576721191 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.047_3389.root.h5 163
# Time spent in fill_evts: 0.0705101490020752 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.048_3389.root.h5 163
# Time spent in fill_evts: 0.061177968978881836 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.049_3389.root.h5 163
# Time spent in fill_evts: 0.07237482070922852 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.050_3389.root.h5 163
# Time spent in fill_evts: 0.06799507141113281 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.051_3389.root.h5 163
# Time spent in fill_evts: 0.09750699996948242 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.052_3389.root.h5 163
# Time spent in fill_evts: 0.09564590454101562 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.053_3389.root.h5 163
# Time spent in fill_evts: 0.06787109375 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.054_3389.root.h5 163
# Time spent in fill_evts: 0.06916999816894531 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.055_3389.root.h5 163
# Time spent in fill_evts: 0.0885322093963623 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.056_3389.root.h5 163
# Time spent in fill_evts: 0.06570577621459961 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.057_3389.root.h5 163
# Time spent in fill_evts: 0.11386489868164062 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.058_3389.root.h5 163
# Time spent in fill_evts: 0.10375404357910156 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.059_3389.root.h5 163
# Time spent in fill_evts: 0.0875101089477539 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.060_3389.root.h5 163
# Time spent in fill_evts: 0.06360292434692383 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.061_3389.root.h5 163
# Time spent in fill_evts: 0.11773991584777832 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.062_3389.root.h5 163
# Time spent in fill_evts: 0.13025498390197754 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.063_3389.root.h5 163
# Time spent in fill_evts: 0.06012606620788574 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.064_3389.root.h5 163
# Time spent in fill_evts: 0.06944704055786133 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.065_3389.root.h5 163
# Time spent in fill_evts: 0.05949211120605469 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.066_3389.root.h5 163
# Time spent in fill_evts: 0.06985187530517578 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.067_3389.root.h5 163
# Time spent in fill_evts: 0.1608438491821289 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.068_3389.root.h5 163
# Time spent in fill_evts: 0.06791496276855469 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.069_3389.root.h5 163
# Time spent in fill_evts: 0.0760188102722168 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.070_3389.root.h5 163
# Time spent in fill_evts: 0.06677794456481934 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.071_3389.root.h5 163
# Time spent in fill_evts: 0.08665609359741211 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.072_3389.root.h5 163
# Time spent in fill_evts: 0.06350207328796387 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.073_3389.root.h5 163
# Time spent in fill_evts: 0.06202411651611328 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.074_3389.root.h5 163
# Time spent in fill_evts: 0.06844782829284668 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.075_3389.root.h5 163
# Time spent in fill_evts: 0.06508398056030273 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.076_3389.root.h5 163
# Time spent in fill_evts: 0.08140397071838379 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.077_3389.root.h5 163
# Time spent in fill_evts: 0.07127690315246582 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.078_3389.root.h5 163
# Time spent in fill_evts: 0.062270164489746094 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.079_3389.root.h5 163
# Time spent in fill_evts: 0.14097118377685547 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.080_3389.root.h5 163
# Time spent in fill_evts: 0.07981085777282715 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.081_3389.root.h5 163
# Time spent in fill_evts: 0.07439613342285156 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.082_3389.root.h5 163
# Time spent in fill_evts: 0.10712099075317383 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.083_3389.root.h5 163
# Time spent in fill_evts: 0.08247208595275879 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.084_3389.root.h5 163
# Time spent in fill_evts: 0.06823015213012695 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.085_3389.root.h5 163
# Time spent in fill_evts: 0.0766000747680664 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.086_3389.root.h5 163
# Time spent in fill_evts: 0.07165098190307617 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.087_3389.root.h5 163
# Time spent in fill_evts: 0.0858919620513916 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.088_3389.root.h5 163
# Time spent in fill_evts: 0.06854677200317383 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.089_3389.root.h5 163
# Time spent in fill_evts: 0.06766986846923828 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.090_3389.root.h5 163
# Time spent in fill_evts: 0.07063102722167969 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.091_3389.root.h5 163
# Time spent in fill_evts: 0.06949114799499512 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.092_3389.root.h5 163
# Time spent in fill_evts: 0.07065391540527344 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.093_3389.root.h5 163
# Time spent in fill_evts: 0.09006285667419434 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2000_3389.root.h5 163
# Time spent in fill_evts: 0.08036184310913086 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2001_3389.root.h5 163
# Time spent in fill_evts: 0.07209515571594238 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2002_3389.root.h5 163
# Time spent in fill_evts: 0.0681309700012207 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2003_3389.root.h5 163
# Time spent in fill_evts: 0.07318806648254395 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2004_3389.root.h5 163
# Time spent in fill_evts: 0.06752395629882812 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2005_3389.root.h5 163
# Time spent in fill_evts: 0.08710503578186035 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2006_3389.root.h5 163
# Time spent in fill_evts: 0.07405495643615723 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2007_3389.root.h5 163
# Time spent in fill_evts: 0.07232904434204102 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2008_3389.root.h5 163
# Time spent in fill_evts: 0.06964111328125 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2009_3389.root.h5 163
# Time spent in fill_evts: 0.0759439468383789 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2010_3389.root.h5 163
# Time spent in fill_evts: 0.07079315185546875 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2011_3389.root.h5 163
# Time spent in fill_evts: 0.08273506164550781 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2012_3389.root.h5 163
# Time spent in fill_evts: 0.1235969066619873 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2013_3389.root.h5 163
# Time spent in fill_evts: 0.08664822578430176 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2014_3389.root.h5 163
# Time spent in fill_evts: 0.08012890815734863 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2015_3389.root.h5 163
# Time spent in fill_evts: 0.06972193717956543 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2016_3389.root.h5 163
# Time spent in fill_evts: 0.07759618759155273 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2017_3389.root.h5 163
# Time spent in fill_evts: 0.0853431224822998 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2018_3389.root.h5 163
# Time spent in fill_evts: 0.07242512702941895 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2019_3389.root.h5 163
# Time spent in fill_evts: 0.12962603569030762 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2020_3389.root.h5 163
# Time spent in fill_evts: 0.10399198532104492 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2021_3389.root.h5 163
# Time spent in fill_evts: 0.07813096046447754 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2022_3389.root.h5 163
# Time spent in fill_evts: 0.06903290748596191 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2023_3389.root.h5 163
# Time spent in fill_evts: 0.1530590057373047 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2024_3389.root.h5 163
# Time spent in fill_evts: 0.07506489753723145 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2025_3389.root.h5 163
# Time spent in fill_evts: 0.12865686416625977 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2026_3389.root.h5 163
# Time spent in fill_evts: 0.0710611343383789 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2027_3389.root.h5 163
# Time spent in fill_evts: 0.10678601264953613 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2028_3389.root.h5 163
# Time spent in fill_evts: 0.10434818267822266 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2029_3389.root.h5 163
# Time spent in fill_evts: 0.07360577583312988 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2030_3389.root.h5 163
# Time spent in fill_evts: 0.08371686935424805 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2031_3389.root.h5 163
# Time spent in fill_evts: 0.0843510627746582 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2032_3389.root.h5 163
# Time spent in fill_evts: 0.08749508857727051 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2033_3389.root.h5 163
# Time spent in fill_evts: 0.17080903053283691 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2034_3389.root.h5 163
# Time spent in fill_evts: 0.10077095031738281 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2035_3389.root.h5 163
# Time spent in fill_evts: 0.09389019012451172 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2036_3389.root.h5 163
# Time spent in fill_evts: 0.11627411842346191 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2037_3389.root.h5 163
# Time spent in fill_evts: 0.10155200958251953 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2038_3389.root.h5 163
# Time spent in fill_evts: 0.08128881454467773 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2039_3389.root.h5 163
# Time spent in fill_evts: 0.07129478454589844 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2040_3389.root.h5 163
# Time spent in fill_evts: 0.10677409172058105 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2041_3389.root.h5 163
# Time spent in fill_evts: 0.11367297172546387 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2042_3389.root.h5 163
# Time spent in fill_evts: 0.1052398681640625 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2043_3389.root.h5 163
# Time spent in fill_evts: 0.07492899894714355 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2044_3389.root.h5 163
# Time spent in fill_evts: 0.10334610939025879 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2045_3389.root.h5 163
# Time spent in fill_evts: 0.07497882843017578 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2046_3389.root.h5 163
# Time spent in fill_evts: 0.06814289093017578 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2047_3389.root.h5 163
# Time spent in fill_evts: 0.0916130542755127 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2048_3389.root.h5 163
# Time spent in fill_evts: 0.07717299461364746 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2049_3389.root.h5 163
# Time spent in fill_evts: 0.08745789527893066 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2050_3389.root.h5 163
# Time spent in fill_evts: 0.07368588447570801 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2051_3389.root.h5 163
# Time spent in fill_evts: 0.07126498222351074 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2052_3389.root.h5 163
# Time spent in fill_evts: 0.07464313507080078 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2053_3389.root.h5 163
# Time spent in fill_evts: 0.07133102416992188 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2054_3389.root.h5 163
# Time spent in fill_evts: 0.07154607772827148 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2055_3389.root.h5 163
# Time spent in fill_evts: 0.07405400276184082 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2056_3389.root.h5 163
# Time spent in fill_evts: 0.07465815544128418 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2057_3389.root.h5 163
# Time spent in fill_evts: 0.07935094833374023 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2200_3389.root.h5 163
# Time spent in fill_evts: 0.13972783088684082 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2201_3389.root.h5 163
# Time spent in fill_evts: 0.10008692741394043 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2202_3389.root.h5 163
# Time spent in fill_evts: 0.12256503105163574 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2400_3389.root.h5 163
# Time spent in fill_evts: 0.11487603187561035 s
# /Users/Gonzalo/github/NEXTdata//Kr2016/data/3389/pmaps_waves.gdcsnext.2401_3389.root.h5 163
# Time spent in fill_evts: 0.08277201652526855 s
# Time spent in _create_attrs: 0.44523119926452637 s
# Time spent in build_dataset: 26.470550060272217 s

# %% [markdown]
# ## General plots about S1 and S2 (no selections applied)

# %%
data = full

# %% [markdown]
# #### Number of S1 and S2 signals

# %%
pdf(data.nS1, 5, range=(0, 5))
labels("# S1", "Entries")
save("NS1")

################################
pdf(data.nS2, 5, range=(0, 5))
labels("# S2", "Entries")
save("NS2")

# %% [markdown]
# <b>
# 1. With the current configuration, the probability of having a number of S2s different than one is negligible: 0.3% for double S2 and <0.1% for missing S2. By allowing shorter S2s we have increased (by a tiny amount) the S2 detection efficiency.
#
# 2. On the other hand, by allowing shorter S1s we have increased the S1 detection efficiency from ~70% to ~95%. The probability of having more than one S1 is negligible.
# </b>

# %% [markdown]
# ## From now on the study is focused on those events with exactly one S1 and one S2

# %%
oneS1oneS2 = full[full.ok]
data = oneS1oneS2
print("Full set   :", full.evts.size, "events")
print("Reduced set:", data.evts.size, "events")
print("Ratio      :", data.evts.size/full.evts.size)
# Out:
# Time spent in _create_attrs: 0.3819401264190674 s
# Full set   : 25591 events
# Reduced set: 14333 events
# Ratio      : 0.5600797155249893

# %%
sel  = flat(oneS1oneS2.S1h)/flat(oneS1oneS2.S1i) > 0.25
data = oneS1oneS2[sel]
# Out:
# Time spent in _create_attrs: 0.07642984390258789 s

# %%
sel = flat(oneS1oneS2.Z>200)
data = oneS1oneS2[sel]
# Out:
# Time spent in _create_attrs: 0.0086669921875 s

# %%
sel = flat(oneS1oneS2.Z>150) & flat(oneS1oneS2.S1w < 150)
data = oneS1oneS2[sel]
# Out:
# Time spent in _create_attrs: 0.022468090057373047 s

# %% [markdown]
# <b>
# The ratio of "reliable" to total events is ~94.0%
# </b>

# %% [markdown]
# ## Distribution of events in Z

# %%
hist(data.Z, 100)
labels("Drift time ($\mu$s)", "Event energy (pes)")
save("Z")

# %% [markdown]
# <b>
# 1. The number of events under these conditions is not uniformly distributed in Z. Near the anode about ~25% of the events lack S1.
# 2. Integrating the lack of events in the whole chamber, we get a Kr detection efficiency of ~94.0%.
# </b>

# %% [markdown]
# ## Width of S1 signals

# %%
s1w = flat(data.S1w)

################################
hist(s1w, 20, range=(0, 500))
labels("S1 width (ns)", "Entries")
save("S1width")

################################
scatter(data.Z, s1w)
x, y, _ = fitf.profileX(data.Z, s1w, 100)
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.polynom, x, y, (1., 1.))
plt.plot(x, f.fn(x), fitOpt)
plt.text(20, 20, "{:.3f} + {:.3f} x".format(*f.values))
labels("Drift time ($\mu$s)", "S1 width (ns)")
plt.ylim(0, 500)
save("S1widthvsZ")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# <b>
# 1. The typical width of an S1 goes up to 400 ns and it looks like it can be even shorter than 100 ns. The distribution peaks at ~160 ns.
# 2. The distribution as a function of Z shows a clear dependence (47% difference between extremes). My explanation for this dependence is the following. When light is isotropically emitted it travels both towards the anode and the cathode. Those going to the anode will reflect in the teflon masks and go back towards the anode. The farther from the anode, the longer it takes to half of the photons (those emitted towards the anode) to reach the cathode.
# </b>

# %% [markdown]
# # Height of S1 signals

# %%
s1h = flat(data.S1h)

################################
hist(s1h, 40, range=(0, 8))
labels("S1 height (pes)", "Entries")
save("S1height")

################################
scatter(data.Z, s1h)
x, y, _ = fitf.profileX(data.Z, s1h, 100)
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.polynom, x, y, (1., 0.8, 0.01))
plt.plot(x, f.fn(x), fitOpt)
plt.text(0, 6, "{:.3g} + {:.3g} x + {:.3g} x^2".format(*f.values))
labels("Drift time ($\mu$s)", "S1 height (pes)")
plt.ylim(0, 7)
save("S1heightvsZ")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# <b>
# 1. The average height of an S1 is around 2 pes, but it grows roughly linearly with z. Near the anode, the height is ~1 pes on average, which is *NOT* high enough to not be confused with noise.
# </b>

# %% [markdown]
# ## S1 energy

# %%
s1i = flat(data.S1i)

################################
hist(s1i, 50, range=(0, 50))
labels("S1 integral (pes)", "Entries")
save("S1energy")

################################
pdf(s1i, 50, range=(0, 50))
labels("S1 integral (pes)", "Entries")
save("S1energy_log")

################################
scatter(data.Z, s1i)
x, y, _ = fitf.profileX(data.Z, s1i, 100)
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.polynom, x, y, (1., 1e-2, 1e-4))
plt.plot(x, f.fn(x), fitOpt)
plt.text(0, 20, "{:.3g} + {:.3g} x + {:.3g} x^2".format(*f.values))
labels("Drift time ($\mu$s)", "S1 energy (pes)")
plt.ylim(0, 25)
save("S1vsZ")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# <b>
# 1. The integrated S1 charge is usually around 7 pes. When the distribution is unfolded in Z, we see that, on average, events near the cathode have 10 pes, while near the anode they have around 4 pes which should be enough for detection.
# </b>

# %% [markdown]
# # S1 width vs S1 energy

# %%
from matplotlib.colors import LogNorm
hist2d(s1i, s1w, (50, 50), range=((0, 20), (0, 500)), norm=LogNorm())

x, y, ye = fitf.profileX(s1i, s1w, 50, (0, 20))
plt.plot(x, y, "k")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## S1 peak-to-area ratio

# %%
################################
y, x, _ = hist(s1h/s1i, 50, range=(0, 0.5))
x = x[:-1] + np.diff(x) * 0.5
f = fitf.fit(fitf.gauss, x, y, (1e5, 0.3, 0.01))
plt.plot(x, f.fn(x), "r")
labels("Peak to area ratio (pes/pes)", "Entries")
save("S1peak2area")
# Out:
# /Users/Gonzalo/github/IC/invisible_cities/core/fit_functions.py:119: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum(np.ma.masked_invalid((fitx - y)**2/y))

# %% [markdown]
# <b>
# 1. The peak to area ratio *was* roughtly gaussianly distributed. Allowing shorter S1s has introduced a slight tail towards high values, but the range is roughtly the same. On average, the ratio is ~26%.
# </b>

# %% [markdown]
# ## Width of S2 signals

# %%
s2w = flat(data.S2w)

################################
hist(s2w, 30, range=(0, 30))
labels("S2 width (ns)", "Entries")
save("S2width")

################################
scatter(data.Z, s2w)
x, y, _ = fitf.profileX(data.Z, s2w, 100)
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.power, x, y, (1., 0.8))
plt.plot(x, f.fn(x), fitOpt)
plt.text(0, 20, "{:.3f} $\cdot$ x^{:.2f}".format(*f.values))
labels("Drift time ($\mu$s)", "S2 width ($\mu$s)")
plt.ylim(0, 30)
save("S2widthvsZ")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# <b>
# 1. The width of a Kr event is ~8 mm, but it depends on z as x^0.4 (although diffussion is ~√ )
# </b>

# %% [markdown]
# # Height of S2 signals

# %%
s2h = flat(data.S2h)

################################
hist(s2h, 40, range=(0, 5e3))
labels("S2 height (pes)", "Entries")
save("S2height")

################################
scatter(data.Z, s2h)
x, y, _ = fitf.profileX(data.Z, s2h, 100)
plt.plot(x, y, profOpt)
fun = lambda x, *args: fitf.expo(x,*args[:2])/fitf.power(x, *args[2:])
f = fitf.fit(fun, x, y, (1., -2e4, 0.1, -0.8))
plt.plot(x, f.fn(x), fitOpt)
plt.text(1e2, 4e3, "{:.3f} exp(x/{:.3g}) / "
                   "({:.3g} $\cdot$ x^{:.2f})".format(*f.values))
labels("Drift time ($\mu$s)", "S2 height (pes)")
plt.ylim(0, 5e3)
save("S2heightvsZ")

################################
scatter(s2w, s2h)
x, y, _ = fitf.profileX(s2w, s2h, 50)
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.power, x, y, (1., -1.0))
plt.plot(x, f.fn(x), fitOpt)
plt.text(10, 4e3, "{:.3f} $\cdot$ x^{:.2f}".format(*f.values))
labels("S2 width ($\mu$s)", "S2 height (pes)")
plt.ylim(0, 5e3)
save("S2heightvsS2width")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# <b>
# 1. The height of an S2 is distributed in a funny manner, but this is just a reflection of its distribution against Z. I don’t really understand the oscillations of the profile for Z < 200 $\mu$s. It is also correlated, as expected, with the width, however, the dependence does not match exactly what I expected (gaussian => h ~ 1/w).
# </b>

# %% [markdown]
# ## S2 energy

# %%
s2i = flat(data.S2i)

################################
hist(s2i, 50, range=(0, 8e3))
labels("S2 integral (pes)", "Entries")
save("S2energy")

################################
pdf(s2i, 50, range=(0, 8e3))
labels("S2 integral (pes)", "Entries")
save("S2energy_log")

################################
scatter(data.Z, s2i)
x, y, _ = fitf.profileX(data.Z, s2i, 100)
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.expo, x, y, (7e3, -1))
plt.plot(x, f.fn(x), fitOpt)
plt.text(0, 2200, "{:.1f} $\cdot$ exp(-x/{:.4g})".format(*f.values))
labels("Drift time ($\mu$s)", "Event energy (pes)")
plt.ylim(2e3, 8e3)
save("EvsZ")

def get_zcorr(f):
    f = copy.copy(f)
    zmax = f(0)
    def zcorr(z):
        return zmax/f(z)
    return zcorr
zcorr = get_zcorr(f.fn)
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/scipy/optimize/minpack.py:715: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %% [markdown]
# <b>
# 1. The integrated Kr S2 signal peaks around 6500 pes, but it depends strongly on the geometrical position of the event (more on that later). When unfolding the distribution in Z, we find that there is a (non-negligible) dependence. The difference is a 2% which for this scale, represents ~110 pes. Since the MC was generated without any type of attachment, this dependence must be introduced somewhere in the IC code (Diomira?, Irene (when performing the deconvolution)?).
# </b>

# %% [markdown]
# ## S2 peak-to-area ratio

# %%
################################
hist(s2h/s2i, 50, range=(0, 0.6))
labels("Peak to area ratio (pes/pes)", "Entries")
save("S2peak2area")

# %% [markdown]
# <b>
# 1. The peak to area ratio seems to be composed of different types of peaks (~0.2, ~0.32, ~0.42, ~0.5). Not yet understood, but surely related to the structure found in the height of S2 signals. The shorter S2s now allowed have increased the significance of these peaks.
# </b>

# %% [markdown]
# ## S2 vs S1

# %%
################################
scatter(s1i, s2i)
x, y, _ = fitf.profileX(s1i, s2i, 100, (0, 20))
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.polynom, x, y, (6e3, -1.))
plt.plot(x, f.fn(x), fitOpt)
plt.text(12, 3200, "{:.3f} + {:.3f} x".format(*f.values))
labels("S1 energy (pes)", "S2 energy (pes)")
plt.xlim(0, 20)
plt.ylim(2e3, 8e3)
save("S2vsS1")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# <b>
# 1. S2 energy is also (anti)correlated with S1 charge. I don’t know where does this come from as there is no recombination in the MC. It may be caused purely by the S2 vs Z dependence.
# 2. The softer S1 and S2 selections have made this dependence stronger (the slope almost doubled).
# </b>

# %% [markdown]
# ## Number of SiPMs touched

# %%
nsipm = flat(data.Nsipm)

################################
hist(nsipm, 10, range=(0, 10))
labels("Number of charged SiPMs", "Entries")
save("Nsipm")

################################
scatter(data.Z, nsipm)
x, y, _ = fitf.profileX(data.Z, nsipm, 100)
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.polynom, x, y, (2, -1e-5, -1e-2, -1e-3))
plt.plot(x, f.fn(x), fitOpt)
plt.text(0, 3.5, "{:.3g} + {:.3g} x + {:.3g} x^2 + {:.3g} x^3".format(*f.values))
labels("Drift time ($\mu$s)", "Number of SiPMs touched")
save("NsipmvsZ")

################################
selection = ~np.isnan(data.R)
R = data.R[selection]
scatter(R, nsipm[selection])
x, y, _ = fitf.profileX(R, nsipm[selection], 50)
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.expo, x, y, (1., -0.8))
plt.plot(x, f.fn(x), fitOpt)
plt.text(0, 3.2, "{:.3f} exp(x/{:.2f})".format(*f.values))
labels("r (mm)", "Number of SiPMs touched")
save("NsipmvsR")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# <b>
# 1. The number of SiPMs with signal over threshold has increased drastically. Now we have at least 4 SiPMs (which is enough for computing the barycenter) most of the time.
# 2. Unfolding the distribution in z tells us that the farther from the anode, the more SiPMs are touched, on average. This has the opposite behaviour than the previous (biased) production. Now, it seems that, as expected, transverse diffusion makes it easier to reach more sensors.
# 3. The number of SiPMs does not depend significantly on the transverse position of the event, as shown.
# 4. The last plot is made with Nsipm>0 (as R would not make sense).
# </b>

# %% [markdown]
# ## To study geometrical dependendes, we will select those events with Nsipm > 0

# %%
atleast1sipm = oneS1oneS2[flat(oneS1oneS2.Nsipm) > 0]
data         = atleast1sipm
# Out:
# Time spent in _create_attrs: 0.41117405891418457 s

# %% [markdown]
# ## Event distribution in the X, Y plane

# %%
X, Y, R, Phi = flat(data.X), flat(data.Y), flat(data.R), flat(data.Phi)

################################
hist(X, 100, range=(-220, 220))
labels("x (mm)", "Entries")
save("X")

################################
hist(Y, 100, range=(-220, 220))
labels("y (mm)", "Entries")
save("Y")

################################
hist(R, 100, range=(0, 220))
labels("r (mm)", "Entries")
save("R")

################################
hist(Phi, 100, range=(-pi, pi))
labels("$\phi$ (rad)", "Entries")
save("Phi")

################################
hist2d(X, Y, 100, range=((-220, 220),
                         (-220, 220)))
plt.colorbar().set_label("# events")
labels("x (mm)", "y (mm)")
save("XY")

################################
hist2d(R, Phi, 100, range=((  0, 220),
                           (-pi, pi )))
plt.colorbar().set_label("# events")
labels("r (mm)", "$\phi$ (mm)")
save("RPhi")

# %% [markdown]
# <b>
# 1. The distribution of events (computed using the barycenter) is, as expected. There is still some "bias" towards the SiPMs positions, but much less than before.
# 2. Because there is a dead SiPM at (5, -155) there is a hole in the number of events there.
# </b>

# %% [markdown]
# ## S2 charge

# %%
################################
s2q = flat(data.Q)
hist(s2q, 100, range=(0, 700))
labels("Tracking plane charge (pes)", "Entries")
save("S2Q")

################################
pdf(s2q, 100, range=(0, 700))
labels("Tracking plane charge (pes)", "Entries")
save("S2Q_log")

# %% [markdown]
# <b>
# 1. The total charge (integral of the tracking plane) is weirdly distributed, but close to a gaussian form. We need to look at its dependences.
# </b>

# %%
################################
scatter(data.Z, s2q)
x, y, _ = fitf.profileX(data.Z, s2q, 100)
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.polynom, x, y, (400, -1, 0.1, 0.01))
plt.plot(x, f.fn(x), fitOpt)
plt.text(50, 600, "{:.3g} + {:.3g} x + {:.3g} x^2 + {:.3g} x^3".format(*f.values))
labels("Drift time ($\mu$s)", "Traking Plane integral (pes)")
save("QvsZ")

################################
sel = fitf.in_range(data.Z, 50, 500)
ave = f.fn(data.Z[sel])
y, x, _ = hist((s2q[sel] - ave)/ave**0.5, 100, range=(-10, 10))
x = x[:-1] + np.diff(x) * 0.5
f = fitf.fit(fitf.gauss, x, y, (1e4, 0, 5))
plt.plot(x, f.fn(x), "r")
labels("Traking Plane integral - average value (pes)", "Entries")
save("QvsZ_shifted")

# %%
nsipm = flat(data.Nsipm)
################################
scatter(nsipm, s2q)
x, y, _ = fitf.profileX(nsipm, s2q, 100, xrange=(0, 10))
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.power, x, y, (100, 0.7))
plt.plot(x, f.fn(x), fitOpt)
plt.text(2.5, 50, "{:.3f} $\cdot$ x^{:.2f}".format(*f.values))
labels("Number of SiPMs touched", "S2 charge (pes)")
save("QvsNsipm")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
################################
plt.figure()
x, y, q, qe = fitf.profileXY(X, Y, s2q, 100, 100)
x = np.repeat(x, x.size)
y = np.tile(y, y.size)
q = np.concatenate(q)
plt.scatter(x, y, c=q, marker="s")
plt.colorbar().set_label("S2 charge (pes)")
labels("x (mm)", "y (mm)")
save("QvsXY")

################################
plt.figure()
x, y, q, qe = fitf.profileXY(R, Phi, s2q, 100, 100)
x = np.repeat(x, x.size)
y = np.tile(y, y.size)
q = np.concatenate(q)
plt.scatter(x, y, c=q, marker="s")
plt.colorbar().set_label("S2 charge (pes)")
labels("r (mm)", "$\phi$ (rad)")
save("QvsRPhi")

################################
scatter(R, s2q)
x, y, _ = fitf.profileX(R, s2q, 50)
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.polynom, x, y, (200, -0.001))
plt.plot(x, f.fn(x), fitOpt)
plt.text(0, 600, "{:.3g} + {:.3g} x".format(*f.values))
labels("r (mm)", "S2 charge (pes)")
save("QvsR")

################################
scatter(Phi, s2q)
x, y, _ = fitf.profileX(Phi, s2q, 100)
plt.plot(x, y, profOpt)
labels("$\phi$ (rad)", "S2 charge (pes)")
save("QvsPhi")

# %% [markdown]
# <b>
# After taking a look to the dependencies of this magnitude we see that:
#     - Charge collection is homogeneous in the TP.
#     - It depends on the number of SiPMs touched ~linearly, but there is a strange bump at Nsipm = 2-3
#     - There is a strong dependence on Z. While events occurring near the anode have ~400 pes, those at the cathode have ~20% less. On the other hand, if we take Q - averageQ for 50 < Z < 500 mus, the distribution seems gaussianly distributed, as expected. Therefore, we can conclude that charge variation in Z is the dominant effect in the TP.
# </b>

# %%
s2e = flat(data.S2i) * zcorr(flat(data.Z))

################################
plt.figure()
x_, y_, q_, qe_ = fitf.profileXY(X, Y, s2e, 100, 100)
x = np.repeat(x_, x_.size)
y = np.tile(y_, y_.size)
q = np.concatenate(q_)
plt.scatter(x, y, c=q, marker="s")
plt.colorbar().set_label("Event energy (pes)")
labels("x (mm)", "y (mm)")
save("EvsXY")

def get_xycorr(xs, ys, qs, qe):
    valid = np.ma.masked_invalid(qe/qs)
    qmax  = np.max(qs)
    xs = xs.reshape(xs.size, 1)
    ys = ys.reshape(ys.size, 1)
    def xycorr(x, y):
        x_closest = np.apply_along_axis(np.argmin, 0, abs(x-xs))
        y_closest = np.apply_along_axis(np.argmin, 0, abs(y-ys))
        return qmax/qs[x_closest, y_closest]
    return xycorr
xycorr = get_xycorr(x_, y_, q_, qe_)

################################
plt.figure()
x, y, q, qe = fitf.profileXY(R, Phi, s2e, 100, 100)
x = np.repeat(x, x.size)
y = np.tile(y, y.size)
q = np.concatenate(q)
plt.scatter(x, y, c=q, marker="s")
plt.colorbar().set_label("S2 energy (pes)")
labels("r (mm)", "$\phi$ (rad)")
save("EvsRPhi")

################################
scatter(R, s2e)
x, y, _ = fitf.profileX(R, s2e, 100)
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.polynom, x, y, (6e3, -1e-2, 1e-2, -1e-3, -1e-4, 1e-6, 1e-7))
plt.plot(x, f.fn(x), fitOpt)
plt.ylim(0, 1e4)
plt.text(0, 3e3, "{:.3g} + {:.3g} x + {:.3g} x^2 + \n"
                 "{:.3g} x^3 + {:.3g} x^4 + {:.3g} x^5 +\n"
                 "{:.3g} x^6".format(*f.values))
labels("r (mm)", "Event energy (pes)")
save("EvsR")

################################
scatter(Phi, s2e)
x, y, _ = fitf.profileX(Phi, s2e, 100)
plt.plot(x, y, profOpt)
labels("$\phi$ (rad)", "Event energy (pes)")
save("EvsPhi")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/ipykernel/__main__.py:15: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# <b>
# 1. Finally, the dependence of the energy with the position is obvious. The behaviour in R and $\phi$ are the ones expected from the parametrization. The Kr energy map seems quite good. The improvement in the number of SiPMs touched has made the map much smoother.
# </b>

# %%
################################
scatter(s2e, s2q)
plt.xlim(3500)
x, y, _ = fitf.profileX(s2e, s2q, 100, (4700, 7200))
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.polynom, x, y, (200, 1e-2, 1e-4))
plt.plot(x, f.fn(x), fitOpt)
plt.text(3600, 700, "{:.3g} + {:.3g} x + {:.3g} x^2".format(*f.values))
labels("S2 energy (pes)", "S2 charge (pes)")
save("QvsE")

# %% [markdown]
# <b>
# 1. The meaning of the charge vs energy plot is not clear. The only dependences are Q(Z) and E(R) (E(z) is negligible compared with the other one), so the quadratic correlation does not seem obvious to me.
# </b>

# %%
################################
qsipm = flat(data.Qsipm)
hist(qsipm, 100, range=(0, 600))
labels("SiPM charge (pes)", "Entries")
save("SipmQ")

################################
pdf(qsipm, 100, range=(0, 600))
labels("SiPM charge (pes)", "Entries")
save("SipmQ_log")

# %% [markdown]
# <b>
# 1. The charge per SiPM shows that the majority of them have less than 100 pes, but, in the best-case scenario, they can reach up to 400 pes. However, since this charge is time-integrated, the lower bound of the distribution is shifted towards the ~5 pes/$\mu$s region, very close to the ZS cut.
# </b>

# %%
################################
order, charge, norm_charge = [], [], []
for evt in data.Qsipm:
    for peak in evt:
        maxq = np.sum(peak)
        for i, q in enumerate(sorted(peak, reverse=True)):
            order.append(i)
            charge.append(q)
            norm_charge.append(q/maxq)

order, charge, norm_charge = map(np.array, [order, charge, norm_charge])
scatter(order, charge)
x, y, _ = fitf.profileX(order, charge, 100, (0, max(order)+1))
plt.plot(x, y, profOpt)
labels("Ordering", "SiPM charge (pes)")
save("SipmQordered")

###########################
scatter(order, norm_charge)
x, y, _ = fitf.profileX(order, norm_charge, 100, (0, max(order)+1))
plt.plot(x, y, profOpt)
labels("Ordering", "SiPM normalized charge (pes/pes)")
save("SipmQnormordered")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Spread of the events

# %%
################################
hist(flat(data.Xrms), 100, range=(0, 10))
labels("rms x (mm)", "Entries")
save("rmsX_full")

################################
hist(flat(data.Yrms), 100, range=(0, 10))
labels("rms y (mm)", "Entries")
save("rmsY_full")

# %% [markdown]
# <b>
# 1. The spread of the event can be measured by the standard deviation of X and Y. In this plot we see a major contribution of those event with Nsipm < 4 at ~5 mm. There is still a tiny fraction of the events that have 1 SiPM or less. We must remove them to continue.
# </b>

# %%
rmsnotzero = data[(data.Xrms > 1e-3) & (data.Yrms > 1e-3)]
data = rmsnotzero
# Out:
# Time spent in _create_attrs: 0.23344898223876953 s

# %%
xrms, yrms = data.Xrms, data.Yrms

################################
hist(xrms, 100, range=(0, 10))
labels("rms x (mm)", "Entries")
save("rmsX")

################################
hist(yrms, 100, range=(0, 10))
labels("rms y (mm)", "Entries")
save("rmsY")

################################
scatter(data.Z, xrms)
x, y, _ = fitf.profileX(data.Z, xrms, 100, yrange=(0,30))
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.polynom, x, y, (1., 0.8))
plt.plot(x, f.fn(x), fitOpt)
plt.text(100, 130, "{:.3f} + {:.3f} x".format(*f.values))
labels("Drift time ($\mu$s)", "rms x (mm)")
save("rmsXvsZ")

################################
scatter(data.Z, yrms)
x, y, _ = fitf.profileX(data.Z, yrms, 100, yrange=(0,30))
plt.plot(x, y, profOpt)
f = fitf.fit(fitf.polynom, x, y, (1., 0.8))
plt.plot(x, f.fn(x), fitOpt)
plt.text(100, 130, "{:.3f} + {:.3f} x".format(*f.values))
labels("Drift time ($\mu$s)", "rms y (mm)")
save("rmsYvsZ")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# <b>
# 1. The same distributions after the second selection are more clear. These are unfolded in Z and it seems that the spread of the event increases slightly with Z.
# </b>

# %%
def reso(values):
    _, mu, sigma = values
    r = 235. * sigma/mu
    return r, r * (41.5/2458)**0.5
E = flat(atleast1sipm.S2i)
Z = flat(atleast1sipm.Z)
X = flat(atleast1sipm.X)
Y = flat(atleast1sipm.Y)

Ecorr = E * zcorr(Z)
Ecorr = E * xycorr(X, Y)

y, x, _ = hist(Ecorr, 200, range=(5.5e3, 9e3))
x = x[:-1] + np.diff(x) * 0.5
f = fitf.fit(fitf.gauss, x, y, (1e5, 7e3, 5e2))
plt.plot(x, f.fn(x), fitOpt)
plt.text(5500, 5e3, ("$\mu$ = {:.1f}\n"
                     "$\sigma$ = {:.2f}\n"
                     "R = {:.3}%\n"
                     "Rbb = {:.3}%").format(*f.values[1:], *reso(f.values)))
labels("Corrected energy (pes)", "Entries")
save("Ecorr")

hist(Ecorr, 200, range=(5.5e3, 9e3))
plt.plot(x, f.fn(x), fitOpt)
plt.yscale("log")
plt.ylim(1, 1e4)
plt.text(5500, 1e3, ("$\mu$ = {:.1f}\n"
                     "$\sigma$ = {:.2f}\n"
                     "R = {:.3}%\n"
                     "Rbb = {:.3}%").format(*f.values[1:], *reso(f.values)))
labels("Corrected energy (pes)", "Entries")
save("Ecorr_log")
# Out:
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/ipykernel/__main__.py:22: RuntimeWarning: divide by zero encountered in true_divide
# /Users/Gonzalo/github/IC/invisible_cities/core/fit_functions.py:119: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum(np.ma.masked_invalid((fitx - y)**2/y))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     225
#     226     if 'png' in formats:
# --> 227         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     228     if 'retina' in formats or 'png2x' in formats:
#     229         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     117
#     118     bytes_io = BytesIO()
# --> 119     fig.canvas.print_figure(bytes_io, **kw)
#     120     data = bytes_io.getvalue()
#     121     if fmt == 'svg':
#
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2242                 orientation=orientation,
#    2243                 bbox_inches_restore=_bbox_inches_restore,
# -> 2244                 **kwargs)
#    2245         finally:
#    2246             if bbox_inches and restore_bbox:
#
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     457         if __debug__: verbose.report('FigureCanvasAgg.draw', 'debug-annoying')
#     458
# --> 459         self.renderer = self.get_renderer(cleared=True)
#     460         # acquire a lock on the shared font cache
#     461         RendererAgg.lock.acquire()
#
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     474
#     475         if need_new_renderer:
# --> 476             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     477             self._lastKey = key
#     478         elif cleared:
#
# /Applications/anaconda3/envs/IC3.5/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      91         self.height = height
#      92         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 514x2046820352 pixels is too large. It must be less than 2^16 in each direction.
